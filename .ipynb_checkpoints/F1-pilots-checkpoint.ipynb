# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# # Daniel Ricciardo Lap Time
#
# Here is the speed that Daniel got on the circuit

# %%
df_ricciardo = pd.read_csv('Ricciardo.csv')

# %%
df_ricciardo
# Out:
#    dist km  speed km/h
# 0        1         320
# 1        2         270
# 2        3          90
# 3        4         190
# 4        5          95
# 5        6         220
# 6        7         300
# 7        8         320

# %%
sn.lineplot(x = 'dist km', y = 'speed km/h', data = df_ricciardo)
plt.show()

# %%
df_vettel = pd.read_csv('Vettel.csv')

# %%
df_vettel
# Out:
#    dist km  speed km/h
# 0        1         308
# 1        2         207
# 2        3         100
# 3        4         184
# 4        5         110
# 5        6         198
# 6        7         302
# 7        8         305

# %%
sn.lineplot(x = 'dist km', y = 'speed km/h', data = df_vettel)
plt.show()

# %%
plt.figure(figsize = (10,5))
sn.lineplot(x = 'dist km', y = 'speed km/h', data = df_vettel)
sn.lineplot(x = 'dist km', y = 'speed km/h', data = df_ricciardo)
plt.show()
